# %% [markdown]
# <a href="https://colab.research.google.com/github/vishmitha-07/SUMMER-ANALYTICS1/blob/main/SA2025_W1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SUMMER ANALYTICS 2025

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
cars=pd.read_csv('Cars.csv')
print(cars)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
print(cars.shape)
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
cols=cars.columns
print(cols)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here
cars['names']=cars['name']
cars=cars.set_index('name')
print(cars)
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin  \
# name
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevy s-10                         19.4          82     usa
#
#                                                names
# name
# chevrolet chevelle malibu  chevrolet chevelle malibu
# buick skylark 320                  buick skylark 320
# plymouth satellite                plymouth satellite
# amc rebel sst                          amc rebel sst
# ford torino                              ford torino
# ...                                              ...
# ford mustang gl                      ford mustang gl
# vw pickup                                  vw pickup
# dodge rampage                          dodge rampage
# ford ranger                              ford ranger
# chevy s-10                                chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
unique_vals = cars['mpg'].unique()
print(f"Unique values in column 'mpg': {list(unique_vals)}")
# Out:
# Unique values in column 'mpg': [np.float64(18.0), np.float64(15.0), np.float64(16.0), np.float64(17.0), np.float64(14.0), np.float64(24.0), np.float64(22.0), np.float64(21.0), np.float64(27.0), np.float64(26.0), np.float64(25.0), np.float64(10.0), np.float64(11.0), np.float64(9.0), np.float64(28.0), np.float64(19.0), np.float64(12.0), np.float64(13.0), np.float64(23.0), np.float64(30.0), np.float64(31.0), np.float64(35.0), np.float64(20.0), np.float64(29.0), np.float64(32.0), np.float64(33.0), np.float64(17.5), np.float64(15.5), np.float64(14.5), np.float64(22.5), np.float64(24.5), np.float64(18.5), np.float64(29.5), np.float64(26.5), np.float64(16.5), np.float64(31.5), np.float64(36.0), np.float64(25.5), np.float64(33.5), np.float64(20.5), np.float64(30.5), np.float64(21.5), np.float64(43.1), np.float64(36.1), np.float64(32.8), np.float64(39.4), np.float64(19.9), np.float64(19.4), np.float64(20.2), np.float64(19.2), np.float64(25.1), np.float64(20.6), np.float64(20.8), np.float64(18.6), np.float64(18.1), np.float64(17.7), np.float64(27.5), np.float64(27.2), np.float64(30.9), np.float64(21.1), np.float64(23.2), np.float64(23.8), np.float64(23.9), np.float64(20.3), np.float64(21.6), np.float64(16.2), np.float64(19.8), np.float64(22.3), np.float64(17.6), np.float64(18.2), np.float64(16.9), np.float64(31.9), np.float64(34.1), np.float64(35.7), np.float64(27.4), np.float64(25.4), np.float64(34.2), np.float64(34.5), np.float64(31.8), np.float64(37.3), np.float64(28.4), np.float64(28.8), np.float64(26.8), np.float64(41.5), np.float64(38.1), np.float64(32.1), np.float64(37.2), np.float64(26.4), np.float64(24.3), np.float64(19.1), np.float64(34.3), np.float64(29.8), np.float64(31.3), np.float64(37.0), np.float64(32.2), np.float64(46.6), np.float64(27.9), np.float64(40.8), np.float64(44.3), np.float64(43.4), np.float64(36.4), np.float64(44.6), np.float64(40.9), np.float64(33.8), np.float64(32.7), np.float64(23.7), np.float64(23.6), np.float64(32.4), np.float64(26.6), np.float64(25.8), np.float64(23.5), np.float64(39.1), np.float64(39.0), np.float64(35.1), np.float64(32.3), np.float64(37.7), np.float64(34.7), np.float64(34.4), np.float64(29.9), np.float64(33.7), np.float64(32.9), np.float64(31.6), np.float64(28.1), np.float64(30.7), np.float64(24.2), np.float64(22.4), np.float64(34.0), np.float64(38.0), np.float64(44.0)]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
cars['hp_per_weight'] = cars['horsepower'] / cars['weight']
cars.set_index('hp_per_weight', inplace=True)
print(cars)
# Out:
#                 mpg  cylinders  displacement  horsepower  weight  \
# hp_per_weight
# 0.037100       18.0          8         307.0       130.0    3504
# 0.044679       15.0          8         350.0       165.0    3693
# 0.043655       18.0          8         318.0       150.0    3436
# 0.043694       16.0          8         304.0       150.0    3433
# 0.040591       17.0          8         302.0       140.0    3449
# ...             ...        ...           ...         ...     ...
# 0.030824       27.0          4         140.0        86.0    2790
# 0.024413       44.0          4          97.0        52.0    2130
# 0.036601       32.0          4         135.0        84.0    2295
# 0.030095       28.0          4         120.0        79.0    2625
# 0.030147       31.0          4         119.0        82.0    2720
#
#                acceleration  model_year  origin                      names
# hp_per_weight
# 0.037100               12.0          70     usa  chevrolet chevelle malibu
# 0.044679               11.5          70     usa          buick skylark 320
# 0.043655               11.0          70     usa         plymouth satellite
# 0.043694               12.0          70     usa              amc rebel sst
# 0.040591               10.5          70     usa                ford torino
# ...                     ...         ...     ...                        ...
# 0.030824               15.6          82     usa            ford mustang gl
# 0.024413               24.6          82  europe                  vw pickup
# 0.036601               11.6          82     usa              dodge rampage
# 0.030095               18.6          82     usa                ford ranger
# 0.030147               19.4          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
#your code here
cars_reset = cars.reset_index()
max_hp_row = cars_reset.loc[cars_reset['horsepower'].idxmax()]

car_name = max_hp_row['names']
print("Car with highest horsepower:", car_name)
# Out:
# Car with highest horsepower: pontiac grand prix

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here
high_mpg_cars = cars[cars['mpg'] >= 35]
print('No of  cars with mpg ≥ 35 : ' ,len(high_mpg_cars))
# Out:
# No of  cars with mpg ≥ 35 :  36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here
filtered_cars = cars[(cars['horsepower'] > 100) & (cars['weight'] < 3000)]
most_common_origin = filtered_cars['origin'].mode()[0]
print('Most common origin for cars with horsepower > 100 and weight < 3000 : ',most_common_origin)
# Out:
# Most common origin for cars with horsepower > 100 and weight < 3000 :  usa

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
japan_cars = cars[cars['origin'] == 'japan']
mean_acceleration = round(japan_cars['acceleration'].mean(), 2)
print(f"The mean acceleration of cars from Japan is: {mean_acceleration}")
# Out:
# The mean acceleration of cars from Japan is: 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
avg_mpg_per_year = cars.groupby('model_year')['mpg'].mean()
best_year = avg_mpg_per_year.idxmax()
highest_avg_mpg = round(avg_mpg_per_year.max(), 2)

print(f"The year with the highest average mpg is: {best_year} with an average mpg of {highest_avg_mpg}")
# Out:
# The year with the highest average mpg is: 80 with an average mpg of 33.7

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
#your code here
median_mpg = cars['mpg'].median()
above_median_mpg = cars[cars['mpg'] > median_mpg].copy()
above_median_mpg['hp_to_weight_ratio'] = above_median_mpg['horsepower'] / above_median_mpg['weight']
max_ratio = above_median_mpg['hp_to_weight_ratio'].max()
best_cars = above_median_mpg[above_median_mpg['hp_to_weight_ratio'] == max_ratio]
print("Car(s) with the best horsepower to weight ratio (among cars with above-median mpg):")
for _, row in best_cars.iterrows():
    print(f"Name: {row['names']}, Horsepower: {row['horsepower']}, Weight: {row['weight']}, MPG: {row['mpg']}, Ratio: {round(row['hp_to_weight_ratio'], 5)}")
# Out:
# Car(s) with the best horsepower to weight ratio (among cars with above-median mpg):
# Name: bmw 2002, Horsepower: 113.0, Weight: 2234, MPG: 26.0, Ratio: 0.05058

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
#your code here
grouped = cars.groupby(['model_year', 'origin'])['mpg'].mean().unstack()

# Plotting
plt.figure(figsize=(10, 6))
for origin in grouped.columns:
    plt.plot(grouped.index, grouped[origin], label=origin)

# Plot customization
plt.title('Average MPG Over the Years by Origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.legend(title='Origin')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
#your code here
features = ['mpg', 'horsepower', 'weight', 'acceleration', 'origin']
data = cars[features]

# Create a PairGrid
g = sns.PairGrid(data, hue='origin', diag_sharey=False)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)
g.add_legend()

plt.suptitle("Seaborn PairGrid of Car Attributes by Origin", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
#your code here
name_grouped = cars.groupby('name')
multi_year_cars = name_grouped.filter(lambda x: x['model_year'].nunique() > 1)
grouped_filtered = multi_year_cars.groupby('name')
consistency_stats = grouped_filtered['mpg'].agg(['std', 'mean', 'count']).reset_index()
consistency_stats.columns = ['name', 'std_mpg', 'avg_mpg', 'count']

consistent_cars = consistency_stats[(consistency_stats['std_mpg'] < 1.0) & (consistency_stats['count'] >= 2)]

consistent_cars_sorted = consistent_cars.sort_values(by=['count', 'avg_mpg'], ascending=[False, False])

# Display result
print("Consistent Car Models (std_mpg < 1.0, at least 2 years):")
print(consistent_cars_sorted[['name', 'count', 'avg_mpg']])
# Out:
# Consistent Car Models (std_mpg < 1.0, at least 2 years):
#                          name  count    avg_mpg
# 26           ford galaxie 500      3  14.333333
# 41          plymouth fury iii      3  14.333333
# 49        toyota corolla 1200      2  31.500000
# 35                  mazda 626      2  31.450000
# 53          volkswagen rabbit      2  29.250000
# 21               datsun pl510      2  27.000000
# 45                  saab 99le      2  24.500000
# 51             toyota mark ii      2  19.500000
# 22                dodge aspen      2  18.850000
# 10  chevrolet chevelle malibu      2  17.500000
# 4            amc matador (sw)      2  14.500000
# 28      ford gran torino (sw)      2  13.500000
# 29                   ford ltd      2  13.500000

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
